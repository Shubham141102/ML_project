# %%
import pandas as pd

# %%
# !pip install pyarrow

# %%
train=pd.read_parquet('Data/train_series.parquet')

# %%
train=pd.read_parquet('Data/Zzzs_train_multi.parquet')

# %%
train['series_id'].unique()
# Out:
# array(['038441c925bb', '03d92c9f6f8a', '0402a003dae9', '04f547b8017d',
#        '05e1944c3818', '062cae666e2a', '062dbd4c95e6', '08db4255286f',
#        '0a96f4993bd7', '0cd1e3d0ed95', '0ce74d6d2106', '0cfc06c129cc',
#        '0d0ad1e77851', '0dee4fda51c3', '0ec9fc461819', '0ef7d94fde99',
#        '0f572d690310', '0f9e60a8e56d', '10469f6765bf', '1087d7b0ff2e',
#        '10f8bc1f7b07', '12d01911d509', '1319a1935f48', '137771d19ca2',
#        '137b99e936ab', '13b4d6a01d27', '148471991ffb', '154fe824ed87',
#        '16fe2798ed0f', '1716cd4163b2', '1762ab70ec76', '188d4b7cd28b',
#        '18a0ca03431d', '18b61dd5aae8', '1955d568d987', '1b92be89db4c',
#        '1c7c0bad1263', '1d4569cbac0f', '1e6717d93c1d', '1f96b9668bdf',
#        '207eded97727', '25e2b3dd9c3b', '2654a87be968', '27f09a6a858f',
#        '280e08693c6d', '292a75c0b94e', '29c75c018220', '29d3469bd15d',
#        '2b0a1fa8eba8', '2b8d87addea9', '2cd2340ca14d', '2e9ced2c7976',
# ...

# %%
new_df = train[train['series_id'] == '72ba4a8afff4']

# %%
# new_df.dtypes

# %%
new_df['timestamp'] = pd.to_datetime(new_df['timestamp'])
# Out:
# <ipython-input-94-802c47375c4b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['timestamp'] = pd.to_datetime(new_df['timestamp'])

# %%
new_df
# Out:
#              series_id    step                 timestamp     anglez    enmo
# 53298000  72ba4a8afff4       0 2018-08-31 17:00:00-04:00 -86.049500  0.0000
# 53298001  72ba4a8afff4       1 2018-08-31 17:00:05-04:00 -86.133797  0.0000
# 53298002  72ba4a8afff4       2 2018-08-31 17:00:10-04:00 -86.120499  0.0000
# 53298003  72ba4a8afff4       3 2018-08-31 17:00:15-04:00 -86.142097  0.0000
# 53298004  72ba4a8afff4       4 2018-08-31 17:00:20-04:00 -86.152298  0.0000
# ...                ...     ...                       ...        ...     ...
# 53690395  72ba4a8afff4  392395 2018-09-23 09:59:35-04:00  -5.475500  0.0557
# 53690396  72ba4a8afff4  392396 2018-09-23 09:59:40-04:00 -11.038400  0.0714
# 53690397  72ba4a8afff4  392397 2018-09-23 09:59:45-04:00 -11.655100  0.1073
# 53690398  72ba4a8afff4  392398 2018-09-23 09:59:50-04:00 -15.002400  0.0509
# 53690399  72ba4a8afff4  392399 2018-09-23 09:59:55-04:00 -13.720800  0.0534
#
# [392400 rows x 5 columns]

# %%
new_df['date'] = new_df['timestamp'].dt.date
# Out:
# <ipython-input-96-ee9086b0f09c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['date'] = new_df['timestamp'].dt.date

# %%
new_df_o  = new_df

# %%
new_df_o['date'] = pd.to_datetime(new_df['date'])
# Out:
# <ipython-input-98-7074563a23fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df_o['date'] = pd.to_datetime(new_df['date'])

# %%
new_df_o
# Out:
#              series_id    step                 timestamp     anglez    enmo  \
# 53298000  72ba4a8afff4       0 2018-08-31 17:00:00-04:00 -86.049500  0.0000
# 53298001  72ba4a8afff4       1 2018-08-31 17:00:05-04:00 -86.133797  0.0000
# 53298002  72ba4a8afff4       2 2018-08-31 17:00:10-04:00 -86.120499  0.0000
# 53298003  72ba4a8afff4       3 2018-08-31 17:00:15-04:00 -86.142097  0.0000
# 53298004  72ba4a8afff4       4 2018-08-31 17:00:20-04:00 -86.152298  0.0000
# ...                ...     ...                       ...        ...     ...
# 53690395  72ba4a8afff4  392395 2018-09-23 09:59:35-04:00  -5.475500  0.0557
# 53690396  72ba4a8afff4  392396 2018-09-23 09:59:40-04:00 -11.038400  0.0714
# 53690397  72ba4a8afff4  392397 2018-09-23 09:59:45-04:00 -11.655100  0.1073
# 53690398  72ba4a8afff4  392398 2018-09-23 09:59:50-04:00 -15.002400  0.0509
# 53690399  72ba4a8afff4  392399 2018-09-23 09:59:55-04:00 -13.720800  0.0534
#
#                date
# 53298000 2018-08-31
# ...

# %%
df_first_20000 = new_df_o.head(17000)

# %%
df_filtered = df_first_20000

# %%
# df_filtered = new_df_o[new_df_o['date'] == '2017-08-31']

# %%
df_filtered['time'] = df_filtered['timestamp'].dt.time
# Out:
# <ipython-input-103-ba4893250cd7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['time'] = df_filtered['timestamp'].dt.time

# %%
df_filtered['time'] = df_filtered['time'].astype(str)
# Out:
# <ipython-input-104-07b6ed201969>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['time'] = df_filtered['time'].astype(str)

# %%
df_filtered
# Out:
#              series_id   step                 timestamp     anglez    enmo  \
# 53298000  72ba4a8afff4      0 2018-08-31 17:00:00-04:00 -86.049500  0.0000
# 53298001  72ba4a8afff4      1 2018-08-31 17:00:05-04:00 -86.133797  0.0000
# 53298002  72ba4a8afff4      2 2018-08-31 17:00:10-04:00 -86.120499  0.0000
# 53298003  72ba4a8afff4      3 2018-08-31 17:00:15-04:00 -86.142097  0.0000
# 53298004  72ba4a8afff4      4 2018-08-31 17:00:20-04:00 -86.152298  0.0000
# ...                ...    ...                       ...        ...     ...
# 53314995  72ba4a8afff4  16995 2018-09-01 16:36:15-04:00  -7.346600  0.2477
# 53314996  72ba4a8afff4  16996 2018-09-01 16:36:20-04:00 -24.280500  0.2680
# 53314997  72ba4a8afff4  16997 2018-09-01 16:36:25-04:00 -21.489700  0.1294
# 53314998  72ba4a8afff4  16998 2018-09-01 16:36:30-04:00 -16.618299  0.0534
# 53314999  72ba4a8afff4  16999 2018-09-01 16:36:35-04:00 -18.447001  0.1845
#
#                date      time
# 53298000 2018-08-31  17:00:00
# ...

# %%
df_filtered['hour'] = df_filtered['time'].str.split(':').str[0]
# Out:
# <ipython-input-106-2c5c0d538002>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['hour'] = df_filtered['time'].str.split(':').str[0]

# %%
df_filtered['hour'].unique()
# Out:
# array(['17', '18', '19', '20', '21', '22', '23', '00', '01', '02', '03',
#        '04', '05', '06', '07', '08', '09', '10', '11', '12', '13', '14',
#        '15', '16'], dtype=object)

# %%
df_filtered
# Out:
#              series_id   step                 timestamp     anglez    enmo  \
# 53298000  72ba4a8afff4      0 2018-08-31 17:00:00-04:00 -86.049500  0.0000
# 53298001  72ba4a8afff4      1 2018-08-31 17:00:05-04:00 -86.133797  0.0000
# 53298002  72ba4a8afff4      2 2018-08-31 17:00:10-04:00 -86.120499  0.0000
# 53298003  72ba4a8afff4      3 2018-08-31 17:00:15-04:00 -86.142097  0.0000
# 53298004  72ba4a8afff4      4 2018-08-31 17:00:20-04:00 -86.152298  0.0000
# ...                ...    ...                       ...        ...     ...
# 53314995  72ba4a8afff4  16995 2018-09-01 16:36:15-04:00  -7.346600  0.2477
# 53314996  72ba4a8afff4  16996 2018-09-01 16:36:20-04:00 -24.280500  0.2680
# 53314997  72ba4a8afff4  16997 2018-09-01 16:36:25-04:00 -21.489700  0.1294
# 53314998  72ba4a8afff4  16998 2018-09-01 16:36:30-04:00 -16.618299  0.0534
# 53314999  72ba4a8afff4  16999 2018-09-01 16:36:35-04:00 -18.447001  0.1845
#
#                date      time hour
# ...

# %%
df_filtered.to_parquet('user35.parquet', index=False)

# %%
import datetime

# %%
# new_df[(new_df['date']>datetime.date(2018,8,2)) & (new_df['date']<datetime.date(2018,5,2))]

# %%
# new_df_spe = new_df['date'] == '2018-02-05'
# new_df_spe = new_df[new_df['date'] == (2018, 02, 05)]
# new_df_spe = new_df.loc[datetime.date(year=2018,month=2,day=5):datetime.date(year=2018,month=2,day=8)]

# new_df_spe = new_df.loc[new_df['date'] == '2018-02-05']

# %%
new_df_spe
# Out:
# Empty DataFrame
# Columns: [series_id, step, timestamp, anglez, enmo, awake, date]
# Index: []

# %%
new_df_oneday = new_df[new_df['timestamp'] == 'af91d9a50547']

# %%
train['series_id'].unique()
# Out:
# array(['08db4255286f', '0a96f4993bd7', '0cfc06c129cc', '1087d7b0ff2e',
#        '10f8bc1f7b07', '18b61dd5aae8', '29c75c018220', '3452b878e596',
#        '349c5562ee2c', '3664fe9233f9', '483d6545417f', '55a47ff9dc8a',
#        '5acc9d63b5fd', '5f94bb3e1bed', '655f19eabf1e', '67f5fc60e494',
#        '72bbd1ac3edf', '76237b9406d5', '7822ee8fe3ec', '89bd631d1769',
#        '8e32047cbc1f', '939932f1822d', '9ee455e4770d', 'a9a2f7fac455',
#        'a9e5f5314bcb', 'af91d9a50547', 'b364205aba43', 'c535634d7dcd',
#        'c6788e579967', 'c68260cc9e8f', 'ca730dbf521d', 'd150801f3145',
#        'd25e479ecbb7', 'd515236bdeec', 'd5e47b94477e', 'a3e59c2ce3f6',
#        'e11b9d69f856', '2fc653ca75c7', '89c7daa72eee', 'c7b1283bb7eb',
#        '390b487231ce', '0f9e60a8e56d', 'c5d08fc3e040'], dtype=object)

# %%
new_df.to_parquet('user16.parquet', index=False)
